# %% [markdown]
# <a href="https://colab.research.google.com/github/Krish-8957/Machine-Learning-From-Scratch/blob/main/logistic_regression_using_gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples=100,
    n_features=2,
    n_redundant=0,
    n_informative=2,
    n_clusters_per_class=1,
    random_state=42
)

w = np.zeros(2)
b = 0

lr = 0.1
epochs = 1000

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

n = len(X)

for i in range(epochs):

    z = np.dot(X, w) + b

    y_hat = sigmoid(z)

    dw = (1/n) * np.dot(X.T, (y_hat - y))

    db = (1/n) * np.sum(y_hat - y)

    w = w - lr * dw

    b = b - lr * db

print("Weights:", w)
print("Bias:", b)

predictions = sigmoid(np.dot(X, w) + b)
predictions = np.where(predictions >= 0.5, 1, 0)

accuracy = np.mean(predictions == y)

print("Accuracy:", accuracy)

plt.scatter(X[:,0], X[:,1], c=y)

x_values = [X[:,0].min(), X[:,0].max()]

y_values = -(w[0] * np.array(x_values) + b) / w[1]

plt.plot(x_values, y_values)

plt.xlabel("X1")
plt.ylabel("X2")

plt.show()
# Out:
# Weights: [-2.1550189   4.01701624]
# Bias: 2.108775368971994
# Accuracy: 1.0
